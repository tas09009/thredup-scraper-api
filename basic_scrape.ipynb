# %%
import pandas as pd
import numpy as np
import re

# %%
df = pd.read_csv('basic_scrape.csv')
df
# Out:
#                                                  Link  \
# 0   https://www.thredup.com/product/women-rayon-ol...
# 1   https://www.thredup.com/product/women-wool-eil...
# 2   https://www.thredup.com/product/women-cotton-a...
# 3   https://www.thredup.com/product/women-cotton-w...
# 4   https://www.thredup.com/product/women-cotton-e...
# 5   https://www.thredup.com/product/women-nylon-an...
# 6   https://www.thredup.com/product/women-polyeste...
# 7   https://www.thredup.com/product/women-banana-r...
# 8   https://www.thredup.com/product/women-polyeste...
# 9   https://www.thredup.com/product/women-cotton-t...
# 10  https://www.thredup.com/product/women-polyeste...
# 11  https://www.thredup.com/product/women-cotton-s...
# 12  https://www.thredup.com/product/women-polyeste...
# 13  https://www.thredup.com/product/women-cotton-c...
# 14  https://www.thredup.com/product/women-cashmere...
# 15  https://www.thredup.com/product/women-cotton-b...
# ...

# %%
df.head()
# Out:
#                                                 Link  \
# 0  https://www.thredup.com/product/women-rayon-ol...
# 1  https://www.thredup.com/product/women-wool-eil...
# 2  https://www.thredup.com/product/women-cotton-a...
# 3  https://www.thredup.com/product/women-cotton-w...
# 4  https://www.thredup.com/product/women-cotton-e...
#
#                                           Image_Link  \
# 0  https://cf-assets-thredup.thredup.com/assets/2...
# 1  https://cf-assets-thredup.thredup.com/assets/2...
# 2  https://cf-assets-thredup.thredup.com/assets/2...
# 3  https://cf-assets-thredup.thredup.com/assets/2...
# 4  https://cf-assets-thredup.thredup.com/assets/2...
#
#                                Materials      Size  \
# 0                  95% Rayon, 5% Spandex   Size S
# 1                              100% Wool   Size S
# 2  55% Cotton, 44% Polyester, 1% Spandex   Size 2
# 3              60% Cotton, 40% Polyester   Size S
# 4  75% Cotton, 24% Polyester, 1% Spandex  Size 2S
#
# ...

# %%
df.columns
# Out:
# Index(['Link', 'Image_Link', 'Materials', 'Size', 'Measurements',
#        'Category_Type'],
#       dtype='object')

# %%
df.shape
# Out:
# (50, 6)

# %%
df_materials = df.Materials.str.contains("Polyester|Polyamide|Acrylic|No Fabric Content")
df_materials
# Out:
# 0     False
# 1     False
# 2      True
# 3      True
# 4      True
# 5     False
# 6      True
# 7      True
# 8      True
# 9     False
# 10     True
# 11    False
# 12     True
# 13     True
# 14    False
# 15    False
# 16     True
# 17    False
# 18     True
# 19     True
# 20    False
# 21    False
# 22     True
# 23    False
# 24     True
# 25     True
# 26    False
# 27     True
# 28    False
# 29     True
# 30    False
# 31     True
# 32    False
# 33     True
# 34    False
# 35    False
# 36    False
# 37     True
# 38     True
# 39     True
# 40     True
# 41     True
# 42    False
# 43    False
# 44    False
# 45     True
# 46    False
# 47    False
# 48    False
# 49    False
# Name: Materials, dtype: bool

# %%
# Reverse the boolyean logic by using '~' in front
df_materials = ~df.Materials.str.contains("Polyester|Polyamide|Acrylic|No Fabric Content")
df[df_materials]
# Out:
#                                                  Link  \
# 0   https://www.thredup.com/product/women-rayon-ol...
# 1   https://www.thredup.com/product/women-wool-eil...
# 5   https://www.thredup.com/product/women-nylon-an...
# 9   https://www.thredup.com/product/women-cotton-t...
# 11  https://www.thredup.com/product/women-cotton-s...
# 14  https://www.thredup.com/product/women-cashmere...
# 15  https://www.thredup.com/product/women-cotton-b...
# 17  https://www.thredup.com/product/women-rayon-ba...
# 20  https://www.thredup.com/product/women-cotton-a...
# 21  https://www.thredup.com/product/women-cotton-b...
# 23  https://www.thredup.com/product/women-silk-stu...
# 26  https://www.thredup.com/product/women-cotton-b...
# 28  https://www.thredup.com/product/women-cotton-a...
# 30  https://www.thredup.com/product/women-wool-ann...
# 32  https://www.thredup.com/product/women-rayon-an...
# 34  https://www.thredup.com/product/women-cotton-b...
# ...
